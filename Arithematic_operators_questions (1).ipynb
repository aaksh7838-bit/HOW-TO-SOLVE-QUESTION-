# %% [markdown]
# # Beginner Python Questions
# Topics: variables, data types, arithmetic operators, print statement

# %% [markdown]
# ## 1. Calculate the Total Bill
# A restaurant bill is ₹450. GST is 18%. Calculate the final bill amount.

# %%
# Write your solution here
restaurant_bill=int(input("enter your bill amount "))
igst=restaurant_bill*18/100
total_bill=restaurant_bill+igst
print(f" total_amount with  Igst 18%  {total_bill}")
# Out:
#  total_amount with  Igst 18%  1062.0

# %% [markdown]
# grocery bill

# %%
bill=int(input("enter your amount "))
sgst=bill*9/100
cgst=bill*9/100
total_bill=bill+sgst+cgst
print(total_bill)
# Out:
# 118.0

# %%
# Out:
#   File "/tmp/ipython-input-4015940835.py", line 1
#     percentage=18%
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 2. Combine Two Numbers
# Create two variables `a = 7` and `b = 3` and compute sum, difference, product, and a^b.

# %%
# Write your solution here
a=7
b=3

print(f"addition:{a+b}")
print(f"sub:{a-b}")
print(f"mult:{a*b}")
print(f"power:{a**b}")
# Out:
# addition:10
# sub:4
# mult:21
# power:343

# %% [markdown]
# ## 3. Temperature Converter
# Convert 36°C to Fahrenheit using F = (C * 9/5) + 32.

# %%
# Write your solution here

temp= 36
Fahrenheit= (temp* 9/5) + 32

print(Fahrenheit)
# Out:
# 96.8

# %% [markdown]
# ## 4. Movie Ticket Cost Calculator
# Movie ticket = 180, popcorn = 120. Calculate total for 2 tickets + 1 popcorn and 3 tickets + 0 popcorn.

# %%
# Write your solution here
how_many_ticket_do_you_have=int(input("enter your ticket quantiy"))
popcorne_do_you_have=int(input("enter your quantiy"))
movie_ticket_price=200
popcorn_price=100
gross_bill=movie_ticket_price*how_many_ticket_do_you_have+popcorn_price*popcorne_do_you_have
gst=gross_bill*18/100
total_bill=gross_bill+gst
print(f"wlecome to my pvr {total_bill} ")
# Out:
# wlecome to my pvr 590.0

# %%
# Want to become data analyst

one_product= 125

total_product= 370

revanue =one_product*total_product

gst= 0.18*revanue

pat= revanue-gst

print(pat)
# Out:
# 37925.0

# %%
revenue_2023= 263.5
revenue_2024=426.5

print(revenue_2023 <= revenue_2024)
# Out:
# True

# %% [markdown]
# ## 5. Area of a Circle
# Radius = 5. Calculate area using 3.14 * r * r.

# %%
# Write your solution here
rad=5
area=3.14*2*rad
print(area)
# Out:
# 31.400000000000002

# %% [markdown]
# com

# %%
age=int(input("Enter your age: "))

if age <18:
  print("not adult")
if age>=18:
     print("Driving license approved hojayega")
# Out:
# Driving license approved hojayega

# %%
name=input("Enter your name: ")
age=int(input("Enter your age: "))


if age <18:
  print(f"{name} wait for {18-age} years")
if age>18:
  print("Driving license approved hojayega")
if age==18:
  print("Driving license approved hojayega")
# Out:
# Enter your name: priya
# Enter your age: 16
# priya wait for 2 years

# %%
age=int(input("age: "))
if age <18:
  print("not elig")
else:
  print("eligible")
# Out:
# age: 21
# eligible
